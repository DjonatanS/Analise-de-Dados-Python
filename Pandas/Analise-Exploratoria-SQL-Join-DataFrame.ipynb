# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_frame = pd.read_csv('taxis_bikes_nycity.csv')

# %%
print(type(data_frame)) #objeto tipo DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data_frame.head()
# Out:
#      Data  Distancia Tempo
# 0  8/2/15       1.70   NaN
# 1  8/3/15       1.40   NaN
# 2  8/4/15       2.10   NaN
# 3  8/6/15       2.38   NaN
# 4  8/7/15       2.30   NaN

# %%
data_frame.dtypes
# Out:
# Data          object
# Distancia    float64
# Tempo         object
# dtype: object

# %%
data_frame.columns
# Out:
# Index(['Data', 'Distancia', 'Tempo'], dtype='object')

# %%
data_frame.index
# Out:
# RangeIndex(start=0, stop=81, step=1)

# %%
data_frame['Data'].head()
# Out:
# 0    8/2/15
# 1    8/3/15
# 2    8/4/15
# 3    8/6/15
# 4    8/7/15
# Name: Data, dtype: object

# %%
data_frame2 = pd.read_csv('taxis_bikes_nycity.csv', parse_dates=['Data']) #Converter para data enquanto importa

# %%
data_frame2['Data'].head()
# Out:
# 0   2015-08-02
# 1   2015-08-03
# 2   2015-08-04
# 3   2015-08-06
# 4   2015-08-07
# Name: Data, dtype: datetime64[ns]

# %%
data_frame2.set_index('Data', inplace=True) #Definir como index a coluna Datas

# %%
data_frame2
# Out:
#             Distancia    Tempo
# Data
# 2015-08-02       1.70      NaN
# 2015-08-03       1.40      NaN
# 2015-08-04       2.10      NaN
# 2015-08-06       2.38      NaN
# 2015-08-07       2.30      NaN
# ...               ...      ...
# 2015-12-24       3.05  0:25:08
# 2015-12-25      14.80  2:20:00
# 2015-12-26       5.20      NaN
# 2015-12-30       3.15  0:22:10
# 2016-01-01      26.20  4:20:43
#
# [81 rows x 2 columns]

# %%
data_frame2.plot()
# Out:
# <AxesSubplot:xlabel='Data'>

# %%
data_frame2.plot(kind='bar') #Grafico de barras
# Out:
# <AxesSubplot:xlabel='Data'>

# %%
data_frame2.plot(kind='area') #Grafico de area
plt.ylabel("Count") #Definir o nome do eixo y como contagem
# Out:
# Text(0, 0.5, 'Count')

# %%
data_frame2.head()
# Out:
#             Distancia Tempo
# Data
# 2015-08-02       1.70   NaN
# 2015-08-03       1.40   NaN
# 2015-08-04       2.10   NaN
# 2015-08-06       2.38   NaN
# 2015-08-07       2.30   NaN

# %%
len(data_frame2['2015-11'])
# Out:
# C:\Users\Djona\AppData\Local\Temp/ipykernel_8684/2568939832.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   len(data_frame2['2015-11'])
# 13

# %%
from datetime import datetime
start = datetime(2015, 8, 1)
end = datetime(2015, 1, 2)

# %%
start = data_frame2.index.min()
end = data_frame2.index.max()

print(start, end)
# Out:
# 2015-08-02 00:00:00 2016-01-01 00:00:00

# %%
data_frame2 = pd.DataFrame(index = pd.date_range(start, end))

# %%
data_frame2.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2015-08-02 00:00:00, 2015-08-03 00:00:00, 2015-08-04 00:00:00, 2015-08-05 00:00:00, 2015-08-06 00:00:00]

# %%
from IPython.display import Image
Image(url='sql-join.png')
# Out:
# <img src="sql-join.png"/>

# %%
data_frame2.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: [2015-08-02 00:00:00, 2015-08-03 00:00:00, 2015-08-04 00:00:00, 2015-08-05 00:00:00, 2015-08-06 00:00:00, 2015-08-07 00:00:00, 2015-08-08 00:00:00, 2015-08-09 00:00:00, 2015-08-10 00:00:00, 2015-08-11 00:00:00]

# %%
data_frame.join(data_frame2).head(10)
# Out:
#       Data  Distancia    Tempo
# 0   8/2/15       1.70      NaN
# 1   8/3/15       1.40      NaN
# 2   8/4/15       2.10      NaN
# 3   8/6/15       2.38      NaN
# 4   8/7/15       2.30      NaN
# 5   8/8/15       3.40      NaN
# 6   8/9/15       2.50      NaN
# 7  8/10/15       3.36  0:28:37
# 8  8/11/15       1.67  0:13:07
# 9  8/12/15       1.42  0:10:35

# %%
data_frame2.join(data_frame).head(10)
# Out:
#                     Data  Distancia Tempo
# 2015-08-02 00:00:00  NaN        NaN   NaN
# 2015-08-03 00:00:00  NaN        NaN   NaN
# 2015-08-04 00:00:00  NaN        NaN   NaN
# 2015-08-05 00:00:00  NaN        NaN   NaN
# 2015-08-06 00:00:00  NaN        NaN   NaN
# 2015-08-07 00:00:00  NaN        NaN   NaN
# 2015-08-08 00:00:00  NaN        NaN   NaN
# 2015-08-09 00:00:00  NaN        NaN   NaN
# 2015-08-10 00:00:00  NaN        NaN   NaN
# 2015-08-11 00:00:00  NaN        NaN   NaN

# %%
data_frame.join(data_frame2, how='outer')
# Out:
#                          Data  Distancia    Tempo
# 2015-08-02 00:00:00       NaN        NaN      NaN
# 2015-08-03 00:00:00       NaN        NaN      NaN
# 2015-08-04 00:00:00       NaN        NaN      NaN
# 2015-08-05 00:00:00       NaN        NaN      NaN
# 2015-08-06 00:00:00       NaN        NaN      NaN
# ...                       ...        ...      ...
# 76                   12/24/15       3.05  0:25:08
# 77                   12/25/15      14.80  2:20:00
# 78                   12/26/15       5.20      NaN
# 79                   12/30/15       3.15  0:22:10
# 80                     1/1/16      26.20  4:20:43
#
# [234 rows x 3 columns]

# %%
data_frame.plot()
# Out:
# <AxesSubplot:>

# %%
data_frame.Distancia.fillna(0, inplace=True)

# %%
data_frame.plot()
# Out:
# <AxesSubplot:>

# %%
data_frame.to_csv('taxis_bikes_nycity_filled.csv')
