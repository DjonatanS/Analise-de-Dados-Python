# %%
import numpy as np
import pandas as pd
import string

# %% [markdown]
# ### Operação com Dataframe

# %%
dict1 = {'Coluna1': [1, 2, 3, 4, 5],
         'Coluna2': [6, 7, 8, 9, 10],
         'Coluna3': [11, 12, 13, 14, 15]}
